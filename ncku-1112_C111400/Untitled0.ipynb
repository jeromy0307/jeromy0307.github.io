# %% [markdown]
# <a href="https://colab.research.google.com/github/jeromy0307/jeromy0307.github.io/blob/master/ncku-1112_C111400/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hellow, World!");
# Out:
# Hellow, World!

# %%
# 第一个注释
# 第二个注释
 
'''
第三注释
第四注释
'''
 
"""
第五注释
第六注释
"""
print ("Hello, Python!")
# Out:
# Hello, Python!

# %%
if True:
    print ("True")
else:
    print ("False")
# Out:
# True

# %% [markdown]
# ```
# total = item_one + \
#      item_two + \
#      item_three
# ```

# %% [markdown]
# Python 通常是一行写完一条语句，但如果语句很长，我们可以使用反斜杠 \ 来实现多行语句，但在 [], {}, 或 () 中的多行语句，不需要使用反斜杠 \

# %% [markdown]
# python中数字有四种类型：整数、布尔型、浮点数和复数。
#
# int (整数), 如 1, 只有一种整数类型 int，表示为长整型，没有 python2 中的 Long。
# bool (布尔), 如 True。
# float (浮点数), 如 1.23、3E-2
# complex (复数), 如 1 + 2j、 1.1 + 2.2j

# %% [markdown]
# 字符串(String)
# Python 中单引号 ' 和双引号 " 使用完全相同。
# 使用三引号(''' 或 """)可以指定一个多行字符串。
# 转义符 \。
# 反斜杠可以用来转义，使用 r 可以让反斜杠不发生转义。 如 r"this is a line with \n" 则 \n 会显示，并不是换行。
# 按字面意义级联字符串，如 "this " "is " "string" 会被自动转换为 this is string。
# 字符串可以用 + 运算符连接在一起，用 * 运算符重复。
# Python 中的字符串有两种索引方式，从左往右以 0 开始，从右往左以 -1 开始。
# Python 中的字符串不能改变。
# Python 没有单独的字符类型，一个字符就是长度为 1 的字符串。
# 字符串的截取的语法格式如下：变量[头下标:尾下标:步长]

# %%
word = '字符串'
sentence = "这是一个句子。"
paragraph = """这是一个段落，
可以由多行组成"""

# %%
#!/usr/bin/python3
 
str='123456789'
 
print(str)                 # 输出字符串
print(str[0:-1])           # 输出第一个到倒数第二个的所有字符
print(str[0])              # 输出字符串第一个字符
print(str[2:5])            # 输出从第三个开始到第五个的字符
print(str[2:])             # 输出从第三个开始后的所有字符
print(str[1:5:2])          # 输出从第二个开始到第五个且每隔一个的字符（步长为2）
print(str * 2)             # 输出字符串两次
print(str + '你好')         # 连接字符串
 
print('------------------------------')
 
print('hello\nrunoob')      # 使用反斜杠(\)+n转义特殊字符
print(r'hello\nrunoob')     # 在字符串前面添加一个 r，表示原始字符串，不会发生转义
# Out:
# 123456789
# 12345678
# 1
# 345
# 3456789
# 24
# 123456789123456789
# 123456789你好
# ------------------------------
# hello
# runoob
# hello\nrunoob

# %%
#!/usr/bin/python3
 
input("\n\n按下 enter 键后退出。")
# Out:
# 按下 enter 键后退出。220
# '220'

# %%
#!/usr/bin/python3
 
import sys; x = 'runoob'; sys.stdout.write(x + '\n')
# Out:
# runoob

# %%
#!/usr/bin/python3

counter = 100          # 整型变量
miles   = 1000.0       # 浮点型变量
name    = "runoob"     # 字符串

print (counter)
print (miles)
print (name)
# Out:
# 100
# 1000.0
# runoob

# %%
a, b, c, d = 20, 5.5, True, 4+3j
print(type(a), type(b), type(c), type(d))
# Out:
# <class 'int'> <class 'float'> <class 'bool'> <class 'complex'>

# %%
xuehao = input("請輸入您的學號 : ")
namezh = input("請輸入您的中文名 : ")
nameen = input("請輸入您的英文名 : ")

print('Hello {nameen}, 你的學號是 {xuehao}, 你的中文姓名是{namezh}'.format(nameen=nameen, namezh=namezh, xuehao=xuehao))
# Out:
# 請輸入您的學號 : C14116190
# 請輸入您的中文名 : 林子閔
# 請輸入您的英文名 : Jeromy
# Hello Jeromy, 你的學號是 C14116190, 你的中文姓名是林子閔

# %%
# Complete the if and elif statements!
def grade_converter(grade):
    if grade>=90:
        return "A"
    elif grade>=80:
        return "B"
    elif grade>=70:
        return "C"
    elif grade>=60:
        return "D"
    else:
        return "F"
print ("Start Test")
# This should print an "A"      
print (grade_converter(92))
 
# This should print a "C"
print (grade_converter(70))
 
# This should print an "F"
print (grade_converter(61))
print ("END \n 程式執行：\n Hi，我是一個成績轉等第的小程式！")
xuehao = input("請輸入您的學號 : ")
namezh = input("請輸入您的中文名 : ")
nameen = input("請輸入您的英文名 : ")
chengji = input("請輸入您的成績：")
chengji = int(chengji)
dengdi = grade_converter(chengji)
print('Hello {nameen}, 你的學號是 {xuehao}, 你的中文姓名是{namezh}, 您成績等第是{dengdi}'.format(nameen=nameen, namezh=namezh, xuehao=xuehao, dengdi=dengdi))
# Out:
# Start Test
# A
# C
# D
# END
#  程式執行：
#  Hi，我是一個成績轉等第的小程式！
# 請輸入您的學號 : C14116190
# 請輸入您的中文名 : 林子閔
# 請輸入您的英文名 : Jeromy LIN
# 請輸入您的成績：99
# Hello Jeromy LIN, 你的學號是 C14116190, 你的中文姓名是林子閔, 您成績等第是A

# %%
input_str = input("請輸入一個字串: ")
if input_str.isalpha():
    input_str = input_str.lower()
    new_str = input_str[1:] + input_str[0] + "ay"
    print(new_str)
else:
    print("輸入錯誤，請輸入英文字母")
#C14116190 林子閔
# Out:
# 請輸入一個字串: abcdefg
# bcdefgaay

# %%
pyg = 'ay'

original = input('Enter a word:')

if len(original) > 0 and original.isalpha():
  word = original.lower() 
  first = word[0]
  new_word = word + first + pyg
  new_word = new_word[1:len(new_word)]
  print (new_word)
else:
  print ('empty')
#C14116190 林子閔
# Out:
# Enter a word:abcdefghijk
# bcdefghijkaay

# %%
def distance_from_zero(s):
  if type(s) == int or type(s) == float:
    return abs(s)
  else:
    return "Nope"
print( distance_from_zero(-3.2))
print( distance_from_zero("test"))
#C14116190 林子閔
# Out:
# 3.2
# Nope

# %%
#C14116190 林子閔 HW5/5
lloyd = {
  "name": "Lloyd",
  "homework": [90.0, 97.0, 75.0, 92.0],
  "quizzes": [88.0, 40.0, 94.0],
  "tests": [75.0, 90.0]
}
alice = {
  "name": "Alice",
  "homework": [100.0, 92.0, 98.0, 100.0],
  "quizzes": [82.0, 83.0, 91.0],
  "tests": [89.0, 97.0]
}
tyler = {
  "name": "Tyler",
  "homework": [0.0, 87.0, 75.0, 22.0],
  "quizzes": [0.0, 75.0, 78.0],
  "tests": [100.0, 100.0]
}

# Add your function below!
def average(numbers):
  total = sum(numbers)
  total = float(total)
  return total/len(numbers)

def get_average(student):
  homework = average(student["homework"])
  quizzes = average(student["quizzes"])
  tests = average(student["tests"])
  return 0.3 * homework + 0.3 * quizzes + 0.4 * tests

def get_letter_grade(score):
  if score >= 90:
    return "A"
  elif score >=80:
    return "B"
  elif score >=70:
    return "C"
  elif score >=65:
    return "D"
  else:
    return "F"

def get_class_average(class_list):
  results = []
  for student in class_list:
    student_avg = get_average(student)
    results.append(student_avg)
  return average(results)

students = [lloyd, alice, tyler]
for student in students:
    student_avg = get_average(student)
    student_grade = get_letter_grade(student_avg)
    print (str(student["name"]) + " " + str(student_avg) + " " + str(student_grade))

average = get_class_average(students)
print(average)
print(get_letter_grade(average))
#C14116190 林子閔 HW5/5
# Out:
# Lloyd 81.75 B
# Alice 92.05 A
# Tyler 69.1 D
# 80.96666666666667
# B

# %%
#C14116190 林子閔 HW5/19
from random import randint

board = []

for x in range(0, 5):
  board.append(["O"] * 5)

def print_board(board):
  for row in board:
    print (" ".join(row))

print_board(board)

def random_row(board):
  return randint(0, len(board) - 1)

def random_col(board):
  return randint(0, len(board[0]) - 1)

ship_row = random_row(board)
ship_col = random_col(board)
'''
print ship_row
print ship_col'
'''

# Everything from here on should be in your for loop
# don't forget to properly indent!
for turn in range(4):
  print ("Turn", turn + 1)
  guess_row = int(input("Guess Row: "))
  guess_col = int(input("Guess Col: "))

  if guess_row == ship_row and guess_col == ship_col:
    print ("Congratulations! You sank my battleship!")
    break
  else:
    if guess_row not in range(5) or \
      guess_col not in range(5):
      print ("Oops, that's not even in the ocean.")
    elif board[guess_row][guess_col] == "X":
      print ("You guessed that one already.")
    else:
      print ("You missed my battleship!")
      board[guess_row][guess_col] = "X"
    if (turn == 3):
      print ("Game Over")
    print_board(board)
#C14116190 林子閔 HW5/19
# Out:
# O O O O O
# O O O O O
# O O O O O
# O O O O O
# O O O O O
# Turn 1
# Guess Row: 0
# Guess Col: 0
# You missed my battleship!
# X O O O O
# O O O O O
# O O O O O
# O O O O O
# O O O O O
# Turn 2
# Guess Row: 1
# Guess Col: 2
# You missed my battleship!
# X O O O O
# O O X O O
# O O O O O
# O O O O O
# O O O O O
# Turn 3
# Guess Row: 1
# Guess Col: 1
# You missed my battleship!
# X O O O O
# O X X O O
# O O O O O
# O O O O O
# O O O O O
# Turn 4
# Guess Row: 4
# Guess Col: 3
# You missed my battleship!
# Game Over
# X O O O O
# O X X O O
# O O O O O
# O O O O O
# O O O X O

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义变量x和k的取值范围
x_vals = np.linspace(-10, 10, 200)
k_vals = np.arange(-9, 10)

# 创建画布
fig, ax = plt.subplots(figsize=(8, 6))

# 绘制曲线
for k in k_vals:
    y_vals = np.sqrt(x_vals**2 - k)
    ax.plot(x_vals, y_vals, label=f'k={k}')
    ax.plot(x_vals, -y_vals, label=f'k={k}')

# 设置图形标题和轴标签
ax.set_title('x^2 - y^2 = k')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend()

# 显示图形
plt.show()
# Out:
# <ipython-input-20-af4a45a1bcf4>:13: RuntimeWarning: invalid value encountered in sqrt
#   y_vals = np.sqrt(x_vals**2 - k)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 定义变量k和x的取值范围
k = input("請輸入k值：")
k = float(k)
x_vals = np.linspace(-10, 10, 200)

# 计算y的值
y_vals = np.sqrt(x_vals**2 - k)

# 创建3D图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制曲线
ax.plot(x_vals, y_vals, np.sqrt(k+x_vals**2-y_vals**2), 'b')
ax.plot(x_vals, -y_vals, np.sqrt(k+x_vals**2-y_vals**2), 'b')
ax.plot(x_vals, y_vals, -np.sqrt(k+x_vals**2-y_vals**2), 'b')
ax.plot(x_vals, -y_vals, -np.sqrt(k+x_vals**2-y_vals**2), 'b')

# 设置图形标题和轴标签
ax.set_title('x^2 - y^2 = {}'.format(k))
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# 显示图形
plt.show()
# Out:
# 請輸入k值：2
# <ipython-input-8-972ae10b82c6>:11: RuntimeWarning: invalid value encountered in sqrt
#   y_vals = np.sqrt(x_vals**2 - k)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 定义变量x和y的取值范围
x_vals = np.linspace(-10, 10, 200)
y_vals = np.linspace(-10, 10, 200)

# 创建x和y的网格
x, y = np.meshgrid(x_vals, y_vals)

# 计算z的值
z = x**2 - y**2

# 创建3D图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制曲面
ax.plot_surface(x, y, z, cmap='coolwarm')

# 设置图形标题和轴标签
ax.set_title('f(x,y) = x^2 - y^2')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# 定义变量x和y的取值范围
x_vals = np.linspace(-10, 10, 200)
y_vals = np.linspace(-10, 10, 200)

# 创建x和y的网格
x, y = np.meshgrid(x_vals, y_vals)

# 计算z的值
z = y**2 - x**2

# 创建3D图形对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制曲面
ax.plot_surface(x, y, z, cmap='coolwarm')

# 设置图形标题和轴标签
ax.set_title('f(x,y) = y^2 - x^2')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# 设置球体的中心坐标
center = [0, 0, 0, 0]

# 设置球体的半径和颜色
radius = 1
color = 'b'

# 设置球体的坐标轴范围
axis_range = [-1, 1]

# 创建画布和3D坐标系对象
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 创建4D球体的顶点坐标
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = radius * np.cos(u) * np.sin(v) + center[0]
y = radius * np.sin(u) * np.sin(v) + center[1]
z = radius * np.cos(v) + center[2]
w = radius * np.sin(u) * np.sin(v) + center[3]

# 创建4D球体的面
verts = []
for i in range(len(x)):
    verts.append(list(zip(x[i], y[i], z[i], w[i])))
sphere = Poly3DCollection(verts, alpha=0.1, facecolor=color, edgecolor='none')
ax.add_collection3d(sphere)

# 设置图形标题和轴标签
ax.set_title('4D Sphere')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(axis_range)
ax.set_ylim(axis_range)
ax.set_zlim(axis_range)

# 显示图形
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-09629a81b98d> in <cell line: 31>()
#      29 for i in range(len(x)):
#      30     verts.append(list(zip(x[i], y[i], z[i], w[i])))
# ---> 31 sphere = Poly3DCollection(verts, alpha=0.1, facecolor=color, edgecolor='none')
#      32 ax.add_collection3d(sphere)
#      33
#
# /usr/local/lib/python3.9/dist-packages/mpl_toolkits/mplot3d/art3d.py in __init__(self, verts, zsort, shade, lightsource, *args, **kwargs)
#     879                     "You must provide facecolors, edgecolors, or both for "
#     880                     "shade to work.")
# --> 881         super().__init__(verts, *args, **kwargs)
#     882         if isinstance(verts, np.ndarray):
#     883             if verts.ndim != 3:
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
# ...
